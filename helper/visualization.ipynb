# %%
from typing import Union
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def load_dataset(file_path: str) -> Union[pd.DataFrame, None]:
    try:
        df = pd.read_csv(file_path)
    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
        return None
    except pd.errors.EmptyDataError:
        print(f"Error: File '{file_path}' is empty.")
        return None
    except pd.errors.ParserError:
        print(f"Error: Unable to parse file '{file_path}'. Please check the file format.")
        return None

    return df

# %%
blue_palette = ['#4285f4', '#64a7f9', '#8cc2f9', '#b3d4f9', '#d0e0f9']
warm_palette = ['#ff7f50', '#ffaa80', '#ffb366', '#ffcc99', '#ffdab9']

def plot_dataframe(ax, file_path: str, label: str=None):
    df = load_dataset(file_path)[['simulation_time', 'real_time']]

    row = df[df['simulation_time']>=10].index.tolist()[0]
    df = df.iloc[:row-1]

    min_value = df['real_time'].min()
    df['real_time'] -= min_value

    print(f"Min Value Simulation Time: {df['simulation_time'].min()}, Max Value Simulation Time: {df['simulation_time'].max()}, Min Value Real Time: {df['real_time'].min()}, Max Value Real Time: {df['real_time'].max()}")

    color = blue_palette if 'cpp' in label else warm_palette
    ax.plot(df.iloc[:, 0], df.iloc[:, 1], label=label, color=random.choice(color))

# %%
fig, axs = plt.subplots(2, figsize=(10, 12))

for i in [1,2,3]:
    file_path = f"../simulation_results/simulation_real_time_python_fastest_visualization_ZigZagProtocolMobile_{i}.csv"
    plot_dataframe(axs[0], file_path=file_path, label=f"ZigZagProtocolMobile_python_{i}")

for i in [7,8,9]:
    file_path = f"../simulation_results/simulation_real_time_cpp_fastest_visualization_ZigZagProtocolMobile_{i}.csv"
    plot_dataframe(axs[0], file_path=file_path, label=f"ZigZagProtocolMobile_cpp_{i}")

axs[0].legend()
axs[0].set_xlabel('Simulation Time in Seconds')
axs[0].set_ylabel('Real Time in Seconds')
axs[0].set_title('Simulation vs. Real Time Mobile - With Visualisation')

for i in [0,4,5]:
    file_path = f"../simulation_results/simulation_real_time_python_fastest_visualization_ZigZagProtocolSensor_{i}.csv"
    plot_dataframe(axs[1], file_path=file_path, label=f"ZigZagProtocolSensor_python_{i}")

for i in [10,11,12]:
    file_path = f"../simulation_results/simulation_real_time_cpp_fastest_visualization_ZigZagProtocolSensor_{i}.csv"
    plot_dataframe(axs[1], file_path=file_path, label=f"ZigZagProtocolSensor_cpp_{i}")

axs[1].legend()
axs[1].set_xlabel('Simulation Time in Seconds')
axs[1].set_ylabel('Real Time in Seconds')
axs[1].set_title('Simulation vs. Real Time Sensors - With Visualisation')
# Out:
# Min Value Simulation Time: 0.01, Max Value Simulation Time: 9.989999999999831, Min Value Real Time: 0.0, Max Value Real Time: 12.251029014587402
# Min Value Simulation Time: 0.01, Max Value Simulation Time: 9.989999999999831, Min Value Real Time: 0.0, Max Value Real Time: 12.250962734222412
# Min Value Simulation Time: 0.01, Max Value Simulation Time: 9.989999999999831, Min Value Real Time: 0.0, Max Value Real Time: 12.25093936920166
# Min Value Simulation Time: 0.0, Max Value Simulation Time: 9.83829415753, Min Value Real Time: 0.0, Max Value Real Time: 1.8600056171417236
# Min Value Simulation Time: 0.0, Max Value Simulation Time: 9.790058639783, Min Value Real Time: 0.0, Max Value Real Time: 1.817533016204834
# Min Value Simulation Time: 0.0, Max Value Simulation Time: 9.790058640759, Min Value Real Time: 0.0, Max Value Real Time: 1.8187236785888672
# ...

# %%
fig1, axs1 = plt.subplots(2, figsize=(10, 12))

for i in [1,2,3]:
    file_path = f"../simulation_results/simulation_real_time_python_express_ZigZagProtocolMobile_{i}.csv"
    plot_dataframe(axs1[0], file_path=file_path, label=f"ZigZagProtocolMobile_python_{i}")

for i in [7,8,9]:
    file_path = f"../simulation_results/simulation_real_time_cpp_express_ZigZagProtocolMobile_{i}.csv"
    plot_dataframe(axs1[0], file_path=file_path, label=f"ZigZagProtocolMobile_cpp_{i}")

axs1[0].legend()
axs1[0].set_xlabel('Simulation Time')
axs1[0].set_ylabel('Real Time')
axs1[0].set_title('Simulation vs. Real Time Mobile - Express')

for i in [0,4,5]:
    file_path = f"../simulation_results/simulation_real_time_python_express_ZigZagProtocolSensor_{i}.csv"
    plot_dataframe(axs1[1], file_path=file_path, label=f"ZigZagProtocolSensor_python_{i}")

for i in [10,11,12]:
    file_path = f"../simulation_results/simulation_real_time_cpp_express_ZigZagProtocolSensor_{i}.csv"
    plot_dataframe(axs1[1], file_path=file_path, label=f"ZigZagProtocolSensor_cpp_{i}")

axs1[1].legend()
axs1[1].set_xlabel('Simulation Time')
axs1[1].set_ylabel('Real Time')
axs1[1].set_title('Simulation vs. Real Time Sensors - Express')
# Out:
# Text(0.5, 1.0, 'Simulation vs. Real Time Sensors - Express')
